# %%
is_mac = False

if is_mac == True:
    baseprompt_filepath = "Data/basePrompt.in"
    instagram_data_filepath = "Data/instagram_raw.csv"
    output_file = "/Users/madhavmalik/VSC Projects/uw-upnext/uw-upnext/public/events.json"
    image_filepath = '/Users/madhavmalik/VSC Projects/uw-upnext/uw-upnext/public/InstagramImages/'
else:
    baseprompt_filepath = "Data/basePrompt.in"
    instagram_data_filepath = "Data/instagram_raw.csv"
    output_file = "../public/events.json"
    image_filepath = "../public/InstagramImages/"

# %%
import pandas as pd
import datetime 
import time
from requests.exceptions import RequestException
from typing import List
import json
from together import Together
import os
from pydantic import BaseModel, Field
from dotenv import load_dotenv
import json
import pandas as pd
from enum import Enum, auto
import re
from pymongo import MongoClient, errors
from pymongo.server_api import ServerApi
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse

basePrompt = open(baseprompt_filepath,"r", encoding = "utf-8").read()

load_dotenv()
togetherAPI = os.getenv('TOGETHER_API')

# %%
#Updating WUSA Events
webpage = requests.get("https://wusa.ca/events/")
jsonscript =str(webpage.content)
isolatedinformation=jsonscript.split('<script type="application/ld+json">')[1].split("</script>")[0][4:-4].encode("utf16", errors="surrogatepass").decode("utf16").encode().decode('unicode_escape')

WUSAjson = json.loads(isolatedinformation.replace('&lt;p&gt;',"").replace("[&hellip;]&lt;/p&gt;\\\\n",""))

wusaDf ={}
postscolumns = ['account','date','caption',"display_photo",'event_details']
wusaDf = pd.DataFrame(columns = postscolumns)

import time

time_now = int(time.time())
for event in WUSAjson:
    if int(datetime.datetime.fromisoformat(event["startDate"]).timestamp()) >= time_now:
        try: 
            location = event["location"]["address"]["streetAddress"]
        except Exception as err:
            print("No street address", str(err))
            location = None
        try:
            new_row = pd.DataFrame({
                    "account": ["WUSA"],
                    "date": [time_now],
                    "caption": str(event["description"])+" [For More Information, Click View Post] ",
                    "display_photo": event["image"],
                    "url": [event['url']],
                    "likes": [0],
                    "event_details": [{
                        "is_event": True,
                        "event_name": event["name"],
                        "event_description": str(event["description"])+" ... ",
                        "categories": ["SOCIAL"],
                        "start_time": int(datetime.datetime.fromisoformat(event["startDate"]).timestamp()),
                        "end_time": int(datetime.datetime.fromisoformat(event["endDate"]).timestamp()),
                        "location": location,
                    }]
            })
            wusaDf = pd.concat([wusaDf, new_row])
            print("success")
        except Exception as error:
            print("Failed row, error:", error)
# Out:
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# Failed row, error: 'image'
# success
# No street address 'streetAddress'
# Failed row, error: 'image'
# success
# No street address 'streetAddress'
# success
# No street address 'streetAddress'
# Failed row, error: 'image'
# No street address 'streetAddress'
# success
# success
# No street address 'location'
# success
# Failed row, error: 'image'
# No street address 'streetAddress'
# success
# success
# No street address 'location'
# success
# success
# success

# %%
together_api_key = os.getenv('TOGETHER_API')


#code for embedding
embedding_model_string = 'BAAI/bge-large-en-v1.5' # model API string from Together.

def generate_embedding(input_texts: List[str], model_api_string: str) -> List[List[float]]:
  together_client = Together(api_key=together_api_key)
  outputs = together_client.embeddings.create(
      input=input_texts,
      model=model_api_string,
  )
  return [x.embedding for x in outputs.data]

insertObjectIds = []

# Set up MongoDB client
uri = os.getenv('DATABASE_URI')
client = MongoClient(uri, server_api=ServerApi('1'))
db = client['Instagram']
collection = db["Events"]

# Remove all documents with 'account': "WUSA"
try:
    result = collection.delete_many({'account': "WUSA"})
    print(f"Documents removed: {result.deleted_count}")
except errors.PyMongoError as e:
    print(f"Error deleting documents: {e}")

# Check and remove '_id' column if present
if '_id' in wusaDf.columns:
    print("DataFrame contains an '_id' column. It will be removed to prevent duplication.")
    wusaDf = wusaDf.drop(columns=['_id'])

for index, row in wusaDf.iterrows():
    # Construct the info string
    info = f'"id": "{int(index)}"|* "account": "{row["account"]}"|* "date": "{row["date"]}"|* "caption": "{row["caption"]}"|*'
    embeddedtext = ',\n'.join(x for x in info.replace('\n','\\n').split('|*')) 

    # Create the document dictionary
    row_dict = {column: row[column] for column in wusaDf.columns.tolist()}
    
    # Add the embedded field
    row_dict["embedded"] = generate_embedding([embeddedtext], embedding_model_string)
    
    # Remove '_id' if present to let MongoDB generate it
    row_dict.pop('_id', None)
    
    try:
        result = collection.insert_one(row_dict)
        print(f"Inserted document ID: {result.inserted_id}")
        insertObjectIds.append(result.inserted_id)
    except errors.DuplicateKeyError as e:
        print(f"DuplicateKeyError: {e}. Document skipped.")
    except errors.PyMongoError as e:
        print(f"An error occurred: {e}. Document skipped.")
    
    time.sleep(0.5)  # Adjust or remove delay as needed

# Optionally, print all inserted ObjectIds
print(f"All inserted document IDs: {insertObjectIds}")
# Out:
# Documents removed: 22
# Inserted document ID: 672979b038120b04865491bd
# Inserted document ID: 672979b138120b04865491be
# Inserted document ID: 672979b238120b04865491bf
# Inserted document ID: 672979b238120b04865491c0
# Inserted document ID: 672979b338120b04865491c1
# Inserted document ID: 672979b438120b04865491c2
# Inserted document ID: 672979b538120b04865491c3
# Inserted document ID: 672979b638120b04865491c4
# Inserted document ID: 672979b738120b04865491c5
# Inserted document ID: 672979b738120b04865491c6
# Inserted document ID: 672979b838120b04865491c7
# Inserted document ID: 672979b938120b04865491c8
# Inserted document ID: 672979ba38120b04865491c9
# Inserted document ID: 672979bb38120b04865491ca
# Inserted document ID: 672979bc38120b04865491cb
# Inserted document ID: 672979bc38120b04865491cc
# Inserted document ID: 672979bd38120b04865491cd
# Inserted document ID: 672979be38120b04865491ce
# Inserted document ID: 672979bf38120b04865491cf
# Inserted document ID: 672979c038120b04865491d0
# Inserted document ID: 672979c138120b04865491d1
# Inserted document ID: 672979c238120b04865491d2
# All inserted document IDs: [ObjectId('672979b038120b04865491bd'), ObjectId('672979b138120b04865491be'), ObjectId('672979b238120b04865491bf'), ObjectId('672979b238120b04865491c0'), ObjectId('672979b338120b04865491c1'), ObjectId('672979b438120b04865491c2'), ObjectId('672979b538120b04865491c3'), ObjectId('672979b638120b04865491c4'), ObjectId('672979b738120b04865491c5'), ObjectId('672979b738120b04865491c6'), ObjectId('672979b838120b04865491c7'), ObjectId('672979b938120b04865491c8'), ObjectId('672979ba38120b04865491c9'), ObjectId('672979bb38120b04865491ca'), ObjectId('672979bc38120b04865491cb'), ObjectId('672979bc38120b04865491cc'), ObjectId('672979bd38120b04865491cd'), ObjectId('672979be38120b04865491ce'), ObjectId('672979bf38120b04865491cf'), ObjectId('672979c038120b04865491d0'), ObjectId('672979c138120b04865491d1'), ObjectId('672979c238120b04865491d2')]

# %%
#Validating if it is an event
load_dotenv()
togetherAPI = os.getenv('TOGETHER_API')
client = Together(api_key=togetherAPI)

postsDf = pd.read_csv(filepath_or_buffer=instagram_data_filepath).replace('"','', regex=True).iloc[2400:2900]
postsDf["is_event"] = pd.NA
postsDf["processed_json"]=pd.NA

def check_string(input_string):
    if any(word in input_string for word in ['yes', 'Yes', 'True', 'true']):
        return True
    elif any(word in input_string for word in ['no', 'No', 'False', 'false']):
        return False
    else:
        return False  # This handles cases where none of the words are found


cnt=0
for index, row in postsDf.iterrows():
    currentjson = f"'account': '{row['account']}'; 'caption': '{row['caption']}'; 'photo_caption': '{row['accessibility_caption']}; 'date_posted_on_instagram: {row['date']}'"
    postsDf.at[index, "processed_json"] = currentjson
    response = client.chat.completions.create(
        model="meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo",
        messages=[{"role": "user", "content": f'Does the following instagram post contain a club event with a specified time. RETURN Yes or No only: {currentjson}'}],
        max_tokens=2
    )
    print(response.choices[0].message.content)
    is_event = check_string(response.choices[0].message.content)
    postsDf.at[index, "is_event"] = is_event
    time.sleep(0.6)
# Out:
# Yes
# No
# No
# No
# No
# No
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# Yes
# No
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# No
# No
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# No
# Yes
# No
# No
# No
# No
# Yes
# No
# No
# Yes
# No
# No
# No
# No
# Yes
# No
# No
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# No
# No
# Yes
# No
# Yes
# No
# No
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# No
# Yes
# No
# Yes
# No
# Yes
# No
# No
# No
# Yes
# No
# No
# No
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# No
# No
# No
# Yes
# No
# Yes
# No
# Yes
# Yes
# Yes
# No
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# No
# No
# No
# No
# Yes
# Yes
# Yes
# Yes
# No
# No
# Yes
# Yes
# Yes
# No
# No
# Yes
# No
# Yes
# No
# Yes
# Yes
# Yes
# Yes
# Yes
# No
# No
# No
# No
# No
# Yes
# No
# No
# No
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# No
# Yes
# No
# No
# Yes
# No
# No
# No
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# No
# Yes
# No
# Yes
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# No
# No
# No
# No
# No
# No
# Yes
# Yes
# No
# No
# Yes
# No
# No
# Yes
# Yes
# Yes
# No
# No
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# Yes
# No
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# Yes
# No
# Yes
# Yes
# Yes
# No
# No
# Yes
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# No
# No
# No
# No
# Yes
# Yes
# No
# No
# Yes
# No
# No
# Yes
# Yes
# Yes
# Yes
# No
# Yes
# No
# Yes
# No
# Yes
# Yes
# Yes
# No
# No
# No
# No
# No
# Yes
# No
# Yes
# Yes
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# No
# Yes
# No
# Yes
# No
# Yes
# Yes
# No
# No
# No
# Yes
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# No
# No
# Yes
# No
# Yes
# No
# Yes
# No
# No
# Yes
# No
# No
# No
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# No
# No
# Yes
# No
# Yes
# No
# No
# No
# No
# No
# Yes
# Yes
# No
# No
# Yes
# Yes
# No
# No
# Yes
# No
# No
# No
# No
# No
# Yes
# No
# No
# No
# Yes
# No
# No
# No
# Yes
# Yes
# No
# No
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# Yes
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# Yes
# Yes
# No
# No
# Yes
# Yes
# Yes
# No
# No
# Yes
# No
# Yes
# Yes
# No
# Yes
# No
# No
# No
# Yes
# No
# No
# No
# No
# No
# Yes
# No
# Yes
# No
# No

# %%
#Functions to Aid in LLM JSON data extraction


client = Together(api_key=togetherAPI)


def remove_emojis(text):
    # Unicode ranges for emojis
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F1E0-\U0001F1FF"  # flags (iOS)
        "\U00002702-\U000027B0"
        "\U000024C2-\U0001F251"
        "]+",
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

class Category(Enum):
    TECH = auto()
    DESIGN = auto()
    SOCIAL = auto()
    ENTERTAINMENT = auto()
    CULTURE = auto()
    SPORTS = auto()
    NETWORKING = auto()
    GAMING = auto()

class Event(BaseModel):
    is_event: bool = Field(description="Whether the post contains an event")
    event_name: str = Field(description="The Name of the Event")
    event_description: str = Field(description='Concise 20 word summary of the event without time or location')
    event_categories: list[str] = Field(description='Categorize the Event into at least one or more of the following: TECH, DESIGN, SOCIAL, MUSIC, CULTURE, SPORTS, NETWORK, GAMING')
    start_time: str = Field(description="The Start time of Event in the format: yyyy-mm-ddTHH:MM:SS+00:00")
    end_time: str = Field(description="The End time of Event in the format: yyyy-mm-ddTHH:MM:SS+00:00")
    location: str = Field(description= "The location of event")

def return_event_details(inputJson : str):
    chat_completion = client.chat.completions.create(
    model = "meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo",
    response_format={"type": "json_object", "schema": Event.model_json_schema()},
    messages=[
        {
            "role": "system",
            "content": basePrompt,
        },
        {
            "role": "user",
            "content": "\n\n Input " + remove_emojis(inputJson) + "\n\n" + "Output",
        },
    ])
    
    created_event = json.loads(chat_completion.choices[0].message.content)
    return created_event

def extract_details_with_error_handling(inputJson, index):
        try: 
            created_event = return_event_details(inputJson)
            return created_event
        except Exception as err:
            print(str(err))
            return {'is_event': False, 'event_name': None, 'start_time': None, 'end_time': None, 'location': None}

postsDf["event_details"] = pd.NA

# %%
import requests
import os
import sys
from pathlib import Path

def download_image(url: str, save_path: str) -> bool:
    """
    Download an image from a URL and save it to the specified path.
    
    Args:
        url (str): The URL of the image to download
        save_path (str): The path where the image should be saved
        
    Returns:
        bool: True if successful, False otherwise
    """
    try:
        # Convert to Path object for better path handling
        save_path = Path(save_path)
        
        # Ensure the filename has a valid extension
        if not save_path.suffix:
            save_path = save_path.with_suffix('.jpg')
            
        # Create the directory if it doesn't exist
        save_path.parent.mkdir(parents=True, exist_ok=True)
        
        # Check write permissions for the directory
        if not os.access(str(save_path.parent), os.W_OK):
            print(f"Error: No write permission for directory: {save_path.parent}")
            return False
            
        # Check if file already exists
        if save_path.exists():
            print(f"Warning: File already exists at {save_path}")
            # You might want to implement a strategy here (skip, overwrite, rename)
            return False
            
        # Download the image
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()  # Raises an HTTPError for bad responses
        except requests.exceptions.RequestException as e:
            print(f"Error downloading image: {e}")
            return False
            
        # Verify the content type is an image
        content_type = response.headers.get('content-type', '')
        if not content_type.startswith('image/'):
            print(f"Error: URL does not point to an image (content-type: {content_type})")
            return False
            
        # Save the image
        try:
            save_path.write_bytes(response.content)
            print(f"Image successfully downloaded to {save_path}")
            return True
        except IOError as e:
            print(f"Error saving image: {e}")
            return False
            
    except Exception as e:
        print(f"Unexpected error: {e}")
        return False

# %%
for index, row in postsDf.iterrows():
    if postsDf.at[index, "is_event"]== True:
        event_details = return_event_details(str(postsDf.at[index, "processed_json"]))
        print(index, event_details)
        try:
            if event_details["event_name"] == None or event_details["start_time"] == None or event_details["end_time"] == None:
                postsDf.at[index, "is_event"] = False
                postsDf.at[index, "event_details"] = None
            else:
                postsDf.at[index, "event_details"] = event_details
                imageurl = row["display_photo"]
                postID = row["url"]
                filepath = image_filepath + postID + ".jpg"
                download_image(imageurl, filepath)
        except Exception as err:
            print(err)
    else: print(index, "no event detected")
# Out:
# 2400 {'is_event': True, 'event_name': 'AI Job Fair', 'event_description': 'AI Job Fair this spring with top innovators', 'event_categories': ['TECH'], 'start_time': '2024-06-06T09:15:00+00:00', 'end_time': 'null', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C7o1TEqgeUh.jpg
# 2401 no event detected
# 2402 no event detected
# 2403 no event detected
# 2404 no event detected
# 2405 no event detected
# 2406 {'is_event': True, 'event_name': 'Towards Trustworthy Human-Machine Collaborations', 'event_description': 'A seminar on advancements in technology and human-machine interaction', 'event_categories': ['TECH'], 'start_time': '2024-05-16T14:00:00+00:00', 'end_time': '2024-05-16T15:00:00+00:00', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C66r0b4gllJ.jpg
# 2407 no event detected
# 2408 no event detected
# 2409 no event detected
# 2410 no event detected
# 2411 no event detected
# 2412 no event detected
# 2413 no event detected
# 2414 no event detected
# 2415 no event detected
# 2416 no event detected
# 2417 no event detected
# 2418 no event detected
# 2419 no event detected
# 2420 no event detected
# 2421 no event detected
# 2422 no event detected
# 2423 {'is_event': True, 'event_name': 'Paths to AI Accountability', 'event_description': 'Talk by Sarah Cen on AI accountability', 'event_categories': ['TECH'], 'start_time': '2024-04-01T10:30:00+00:00', 'end_time': '2024-04-01T11:30:00+00:00', 'location': 'DC 1304'}
# Image successfully downloaded to ..\public\InstagramImages\C5EjyelAHzZ.jpg
# 2424 {'is_event': True, 'event_name': 'Undergrad AI Showcase', 'event_description': 'Undergrad AI Showcase on April 2nd', 'event_categories': ['TECH'], 'start_time': '2024-04-02 00:00:00+00:00', 'end_time': '2024-04-02 00:00:00+00:00', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C5EhjzQA44y.jpg
# 2425 no event detected
# 2426 {'is_event': True, 'event_name': 'Generative AI Talk', 'event_description': 'Talk on Generative AI for Robot Autonomy', 'event_categories': ['TECH'], 'start_time': '2024-03-20T11:00:00+00:00', 'end_time': '2024-03-20T12:00:00+00:00', 'location': 'EIT 3142'}
# Image successfully downloaded to ..\public\InstagramImages\C4taXQYudJi.jpg
# 2427 no event detected
# 2428 no event detected
# 2429 no event detected
# 2430 no event detected
# 2431 no event detected
# 2432 no event detected
# 2433 no event detected
# 2434 no event detected
# 2435 no event detected
# 2436 no event detected
# 2437 no event detected
# 2438 no event detected
# 2439 no event detected
# 2440 no event detected
# 2441 {'is_event': True, 'event_name': 'Reality Labs Welcome Event', 'event_description': 'Welcome new members, learn about projects, showcase XR, and meet fellow members', 'event_categories': ['TECH'], 'start_time': '2024-09-28T19:00:00+00:00', 'end_time': '2024-09-28T21:00:00+00:00', 'location': 'E5-2004'}
# Image successfully downloaded to ..\public\InstagramImages\DATZvv0ubkh.jpg
# 2442 no event detected
# 2443 no event detected
# 2444 no event detected
# 2445 no event detected
# 2446 no event detected
# 2447 no event detected
# 2448 no event detected
# 2449 no event detected
# 2450 no event detected
# 2451 no event detected
# 2452 {'is_event': True, 'event_name': 'WUSA Thrift Sale', 'event_description': 'Shop and sip at WUSA Thrift on Nov 5th. Prices under $10. Free refreshments for Waterloo undergrads', 'event_categories': ['CULTURE'], 'start_time': '2024-11-05T11:00:00+00:00', 'end_time': '2024-11-05T14:00:00+00:00', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\DByvgUGAym0.jpg
# 2453 no event detected
# 2454 no event detected
# 2455 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\DBtcaYZuZ5F.jpg
# 2456 no event detected
# 2457 no event detected
# 2458 no event detected
# 2459 no event detected
# 2460 no event detected
# 2461 no event detected
# 2462 no event detected
# 2463 no event detected
# 2464 no event detected
# 2465 {'is_event': True, 'event_name': 'Oktoberfest', 'event_description': 'German celebration with music, dancing, and food', 'event_categories': ['CULTURE'], 'start_time': '2024-10-16T18:00:00+00:00', 'end_time': '2024-10-16T01:00:00+00:00', 'location': 'Concordia Club, Kitchener'}
# Image successfully downloaded to ..\public\InstagramImages\DA9Miw5Snrm.jpg
# 2466 no event detected
# 2467 {'is_event': True, 'event_name': 'WUSA Halloween Haunt', 'event_description': "Halloween event at Canada's Wonderland with rides and scare zones", 'event_categories': ['MUSIC', 'NETWORK', 'SPORTS', 'WELLNESS'], 'start_time': '2024-10-26T16:30:00+00:00', 'end_time': '2024-10-26T01:45:00+00:00', 'location': "Canada's Wonderland, Vaughan"}
# Image successfully downloaded to ..\public\InstagramImages\DA3_7vgSb_M.jpg
# 2468 no event detected
# 2469 no event detected
# 2470 no event detected
# 2471 no event detected
# 2472 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\DAjf-x8ylkr.jpg
# 2473 no event detected
# 2474 no event detected
# 2475 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\DAbZ2S7guO7.jpg
# 2476 no event detected
# 2477 no event detected
# 2478 no event detected
# 2479 no event detected
# 2480 {'is_event': True, 'event_name': 'The Jack Talk', 'event_description': 'A virtual event on mental health support', 'event_categories': ['WELLNESS'], 'start_time': '2024-09-25T12:00:00+00:00', 'end_time': '2024-09-25T13:30:00+00:00', 'location': 'Virtual Event'}
# Image successfully downloaded to ..\public\InstagramImages\DAGY1kouuYD.jpg
# 2481 no event detected
# 2482 no event detected
# 2483 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C_wECssJT37.jpg
# 2484 {'is_event': True, 'event_name': 'Thrift Tea', 'event_description': 'Thrift Tea: Sustainable styles and budget friendly pricing', 'event_categories': ['CULTURE', 'DESIGN', 'WELLNESS'], 'start_time': '2024-09-18T11:00:00+00:00', 'end_time': '2024-09-18T14:00:00+00:00', 'location': 'SLC Multi-Purpose Room'}
# Image successfully downloaded to ..\public\InstagramImages\C_vz2dPpbf3.jpg
# 2485 {'is_event': True, 'event_name': 'Campus Life Fair', 'event_description': 'Learn about services and pick up free swag at the Campus Life Fair', 'event_categories': ['CULTURE'], 'start_time': '2024-09-18T11:00:00+00:00', 'end_time': '2024-09-18T14:00:00+00:00', 'location': 'SLC Great Hall'}
# Image successfully downloaded to ..\public\InstagramImages\C_vbGhIAk_7.jpg
# 2486 {'is_event': True, 'event_name': 'WUSA Bowling Experience', 'event_description': "Bowling experience at Waterloo's newest bowling alley with @splitsvillefun", 'event_categories': ['SPORTS'], 'start_time': '2024-09-12T00:00:00+00:00', 'end_time': '2024-09-12T00:45:00+00:00', 'location': "Waterloo's newest bowling alley"}
# Image successfully downloaded to ..\public\InstagramImages\C_tDnneAOhh.jpg
# 2487 {'is_event': True, 'event_name': 'Concert with Dillon Francis', 'event_description': 'Concert with Dillon Francis, opening acts: @twentyfiveroses.music and @tysloyens', 'event_categories': ['MUSIC'], 'start_time': '2024-09-07T00:00:00+00:00', 'end_time': 'null', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C_nXtg7xXoJ.jpg
# 2488 {'is_event': True, 'event_name': 'Concert', 'event_description': 'Concert with @uwaterloolife and CIBC, tickets available in bio', 'event_categories': ['MUSIC'], 'start_time': 'null', 'end_time': 'null', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C_mFUkFxh9n.jpg
# 2489 {'is_event': True, 'event_name': 'WUSA x UWaterloo Dillon Francis Concert', 'event_description': 'Last chance to win $5000 in our giveaway', 'event_categories': ['MUSIC'], 'start_time': '2024-09-07', 'end_time': '2024-09-07', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C_lwer-x551.jpg
# 2490 {'is_event': True, 'event_name': 'Dillon Francis Concert', 'event_description': 'See Dillon Francis at the biggest party of the year', 'event_categories': ['MUSIC'], 'start_time': 'Unknown', 'end_time': 'Unknown', 'location': 'Unknown'}
# Image successfully downloaded to ..\public\InstagramImages\C_lfB1_xiPM.jpg
# 2491 no event detected
# 2492 no event detected
# 2493 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C_jHxOXSeIw.jpg
# 2494 no event detected
# 2495 {'is_event': True, 'event_name': "yourWUSA's Fall BBQ Smash", 'event_description': 'BBQ vibes and good times at Fall BBQ Smash with SmashBites', 'event_categories': ['CULTURE'], 'start_time': '2024-09-11T11:30:00+00:00', 'end_time': '2024-09-11T12:00:00+00:00', 'location': 'SLC Student Lounge'}
# Image successfully downloaded to ..\public\InstagramImages\C_iwZCZgkgX.jpg
# 2496 no event detected
# 2497 no event detected
# 2498 {'is_event': True, 'event_name': 'WUSA Carnival', 'event_description': 'Carnival for TWO NIGHTS with rides, games, and fun', 'event_categories': ['CULTURE'], 'start_time': '2024-09-10T18:00:00+00:00', 'end_time': '2024-09-10T23:59:00+00:00', 'location': 'BMH, M3 & SLC Greens'}
# Image successfully downloaded to ..\public\InstagramImages\C_gLmeaggQc.jpg
# 2499 {'is_event': True, 'event_name': 'Sex Toy Bingo', 'event_description': 'Add spice to Fall semester with Sex Toy Bingo at FED Hall', 'event_categories': ['MUSIC', 'CULTURE', 'SPORTS'], 'start_time': '2024-09-09T20:00:00+00:00', 'end_time': 'nan', 'location': 'FED Hall'}
# Image successfully downloaded to ..\public\InstagramImages\C_f78vIgMCN.jpg
# 2500 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C_eP-8pgCaL.jpg
# 2501 {'is_event': True, 'event_name': 'WUSA Welcome Brunch', 'event_description': 'Free Welcome Brunch with vegan and gluten-free options', 'event_categories': ['CULTURE'], 'start_time': '2024-09-09T09:30:00+00:00', 'end_time': 'None', 'location': 'BMH Green'}
# Image successfully downloaded to ..\public\InstagramImages\C_dvCEmRZNS.jpg
# 2502 {'is_event': True, 'event_name': 'Ready to Slay Your Game', 'event_description': 'Welcome Week esports event at the SLC Black & Gold Room', 'event_categories': ['GAMING'], 'start_time': '2024-09-09T10:00:00+00:00', 'end_time': '2024-09-12T22:00:00+00:00', 'location': 'SLC Black & Gold Room.'}
# Image successfully downloaded to ..\public\InstagramImages\C_dr6QnRNZA.jpg
# 2503 {'is_event': True, 'event_name': 'WUSA First Year Fair', 'event_description': 'Discover what it means to be part of WUSA and connect with your peers', 'event_categories': ['CULTURE'], 'start_time': '2024-09-05T11:00:00+00:00', 'end_time': '2024-09-05T14:00:00+00:00', 'location': 'SLC Green'}
# Image successfully downloaded to ..\public\InstagramImages\C_dpN7bOQb0.jpg
# 2504 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C_dXPypAGCh.jpg
# 2505 no event detected
# 2506 {'is_event': True, 'event_name': 'WUSA x UWaterloo Dillon Francis Concert', 'event_description': 'Win $5000 at the WUSA x UWaterloo Dillon Francis Concert', 'event_categories': ['MUSIC'], 'start_time': '2024-09-07', 'end_time': 'No end time specified', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C_YA3TQOtyB.jpg
# 2507 no event detected
# 2508 {'is_event': True, 'event_name': 'BIGGEST party of the year', 'event_description': 'Concert with Dillon Francis, opening acts twentyfiveroses.music and TYS LOYENS', 'event_categories': ['MUSIC'], 'start_time': '2024-09-07T00:00:00+00:00', 'end_time': 'nan', 'location': 'nan'}
# Image successfully downloaded to ..\public\InstagramImages\C_TFdVgA6Sw.jpg
# 2509 no event detected
# 2510 {'is_event': True, 'event_name': 'Your WUSA Concert', 'event_description': 'concert with @twentyfiveroses.music and @tysloyens', 'event_categories': ['MUSIC'], 'start_time': '2024-09-07T18:15:00+00:00', 'end_time': 'null', 'location': 'North Campus, Field 7'}
# Image successfully downloaded to ..\public\InstagramImages\C_RJR6QPCUb.jpg
# 2511 no event detected
# 2512 no event detected
# 2513 no event detected
# 2514 {'is_event': True, 'event_name': 'Dillon Francis', 'event_description': 'Tickets for Dillon Francis on Sept. 7', 'event_categories': ['MUSIC'], 'start_time': '2024-09-07T00:00:00+00:00', 'end_time': 'null', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C-3v0hvg4ZB.jpg
# 2515 no event detected
# 2516 no event detected
# 2517 no event detected
# 2518 {'is_event': True, 'event_name': 'Dillion Francis Concert', 'event_description': 'Concert with Dillion Francis on September 7th', 'event_categories': ['MUSIC'], 'start_time': '2024-09-07T00:00:00+00:00', 'end_time': '2024-09-07T00:00:00+00:00', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C-tU7gMAn1e.jpg
# 2519 no event detected
# 2520 no event detected
# 2521 no event detected
# 2522 no event detected
# 2523 no event detected
# 2524 no event detected
# 2525 no event detected
# 2526 no event detected
# 2527 no event detected
# 2528 no event detected
# 2529 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C-VMmWjgQ_p.jpg
# 2530 no event detected
# 2531 no event detected
# 2532 no event detected
# 2533 no event detected
# 2534 no event detected
# 2535 no event detected
# 2536 no event detected
# 2537 no event detected
# 2538 no event detected
# 2539 no event detected
# 2540 no event detected
# 2541 no event detected
# 2542 no event detected
# 2543 no event detected
# 2544 no event detected
# 2545 no event detected
# 2546 no event detected
# 2547 no event detected
# 2548 no event detected
# 2549 no event detected
# 2550 no event detected
# 2551 no event detected
# 2552 no event detected
# 2553 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C9NpPsoRPOF.jpg
# 2554 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C9LAgQ6JusU.jpg
# 2555 no event detected
# 2556 no event detected
# 2557 no event detected
# 2558 no event detected
# 2559 no event detected
# 2560 no event detected
# 2561 no event detected
# 2562 no event detected
# 2563 no event detected
# 2564 no event detected
# 2565 no event detected
# 2566 no event detected
# 2567 no event detected
# 2568 no event detected
# 2569 no event detected
# 2570 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C7edOUAg8hC.jpg
# 2571 no event detected
# 2572 no event detected
# 2573 no event detected
# 2574 {'is_event': True, 'event_name': 'Taylor & Friend’s Dance Party', 'event_description': 'Today at Taylor & Friend’s Dance Party! Open to Waterloo undergraduate students and their guests', 'event_categories': ['MUSIC'], 'start_time': '2024-05-16T21:00:00+00:00', 'end_time': '2024-05-16T23:00:00+00:00', 'location': 'SLC Student Lounge'}
# Image successfully downloaded to ..\public\InstagramImages\C7B7jdFgQO9.jpg
# 2575 no event detected
# 2576 {'is_event': True, 'event_name': "Taylor & Friend's Dance Party", 'event_description': 'Join us at the Taylor & Friends Dance Party', 'event_categories': ['MUSIC'], 'start_time': '2024-05-16T21:00:00+00:00', 'end_time': 'null', 'location': 'SLC Student Lounge'}
# Image successfully downloaded to ..\public\InstagramImages\C6_chkug6mW.jpg
# 2577 no event detected
# 2578 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C663S-Bgg8v.jpg
# 2579 {'is_event': True, 'event_name': "WUSA's Karaoke Night", 'event_description': 'Karaoke Night with drinks and snacks available for purchase', 'event_categories': ['MUSIC'], 'start_time': '2024-05-13T21:00:00+00:00', 'end_time': 'null', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C66vQ91AS8S.jpg
# 2580 {'is_event': True, 'event_name': 'Retro Skate Night', 'event_description': 'Join us at Retro Rollers on May 15th from 9-12 am', 'event_categories': ['SPORTS'], 'start_time': '2024-05-15T09:00:00+00:00', 'end_time': '2024-05-15T12:00:00+00:00', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C6y6-e1ApK4.jpg
# 2581 no event detected
# 2582 {'is_event': True, 'event_name': "Taylor & Friend's Dance Party", 'event_description': "Join us at the Taylor & Friend's Dance Party for a night of music and dancing", 'event_categories': ['MUSIC'], 'start_time': '2024-05-16T21:00:00+00:00', 'end_time': 'null', 'location': 'SLC Student Lounge'}
# Image successfully downloaded to ..\public\InstagramImages\C6yuHR4gI61.jpg
# 2583 {'is_event': True, 'event_name': 'Retro Skate Night', 'event_description': 'Join us for a night of roller skating at the Board Walk', 'event_categories': ['SPORTS'], 'start_time': '2024-05-15T21:00:00+00:00', 'end_time': '2024-05-15T00:00:00+00:00', 'location': 'The Board Walk'}
# Image successfully downloaded to ..\public\InstagramImages\C6wbWvYJYcy.jpg
# 2584 {'is_event': True, 'event_name': 'Sex Toy Bingo', 'event_description': 'A Welcome Week favourite with two all-ages shows and prizes', 'event_categories': ['CULTURE'], 'start_time': '2024-05-14T19:00:00+00:00', 'end_time': '2024-05-14T21:30:00+00:00', 'location': 'SLC Student Lounge'}
# Image successfully downloaded to ..\public\InstagramImages\C6wM0w8AGc3.jpg
# 2585 {'is_event': True, 'event_name': 'Esports Gaming Lounge', 'event_description': 'Gaming lounge for Spring Welcome Week', 'event_categories': ['GAMING'], 'start_time': '2024-05-13T10:00:00+00:00', 'end_time': '2024-05-16T22:00:00+00:00', 'location': 'SLC Black & Gold Room'}
# Image successfully downloaded to ..\public\InstagramImages\C6tZLq7A-d9.jpg
# 2586 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C6rdE4hAG0x.jpg
# 2587 {'is_event': True, 'event_name': "WUSA's Karaoke Night", 'event_description': 'Karaoke night for Waterloo undergrad students and their guests', 'event_categories': ['MUSIC'], 'start_time': '2024-05-13T21:00:00+00:00', 'end_time': '2024-05-14T02:00:00+00:00', 'location': 'Revive Karaoke in Uptown Waterloo'}
# Image successfully downloaded to ..\public\InstagramImages\C6rTT6cg1hA.jpg
# 2588 {'is_event': True, 'event_name': 'Welcome BBQ', 'event_description': 'FREE food, including halal beef burgers, vegan choices and gluten-free options', 'event_categories': ['CULTURE'], 'start_time': '2024-05-13T11:30:00+00:00', 'end_time': '2024-05-13T12:00:00+00:00', 'location': 'SLC, near the Bomber patio behind the green'}
# Image successfully downloaded to ..\public\InstagramImages\C6ouRUAMAzm.jpg
# 2589 no event detected
# 2590 no event detected
# 2591 no event detected
# 2592 no event detected
# 2593 no event detected
# 2594 no event detected
# 2595 no event detected
# 2596 no event detected
# 2597 no event detected
# 2598 no event detected
# 2599 no event detected
# 2600 no event detected
# 2601 no event detected
# 2602 {'is_event': True, 'event_name': 'Bowling Event', 'event_description': 'Bowling event for club executives, society executives, governance members, and O-team', 'event_categories': ['NETWORK'], 'start_time': '2024-03-26T13:00:00+00:00', 'end_time': 'null', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C480nZ5AUF1.jpg
# 2603 no event detected
# 2604 no event detected
# 2605 no event detected
# 2606 no event detected
# 2607 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C4vzB3QKKpj.jpg
# 2608 {'is_event': True, 'event_name': "WUSA's Annual General Meeting", 'event_description': 'Annual General Meeting with poutine bar and 50% off cold beverages', 'event_categories': ['WUSA', 'CULTURE'], 'start_time': '2024-03-27T17:00:00+00:00', 'end_time': 'null', 'location': 'SLC Great Hall'}
# Image successfully downloaded to ..\public\InstagramImages\C4vkyUogEoF.jpg
# 2609 {'is_event': True, 'event_name': 'Yourwusa Nationals Semis', 'event_description': 'Semifinals vs. Concordia on Saturday', 'event_categories': ['SPORTS'], 'start_time': '2024-03-16T18:00:00+00:00', 'end_time': '2024-03-16T00:00:00+00:00', 'location': 'Black and Gold Room, SLC'}
# Image successfully downloaded to ..\public\InstagramImages\C4k1B47Aqav.jpg
# 2610 {'is_event': True, 'event_name': "WUSA's St. Patrick’s Day Trivia", 'event_description': 'Join us for WUSA’s special St. Patrick’s Day Trivia event', 'event_categories': ['CULTURE', 'NETWORK'], 'start_time': '2024-03-18T19:30:00+00:00', 'end_time': 'None', 'location': 'SLC Student Lounge 1123'}
# Image successfully downloaded to ..\public\InstagramImages\C4gU4nAg5y7.jpg
# 2611 no event detected
# 2612 no event detected
# 2613 {'is_event': True, 'event_name': 'Therapy Dogs on Campus', 'event_description': 'Meet our Therapy Dogs with SVPRO, Wednesday, March 13th', 'event_categories': ['WELLNESS'], 'start_time': '2024-03-13T15:00:00+00:00', 'end_time': '2024-03-13T16:00:00+00:00', 'location': 'SLC Multi-Purpose Room'}
# Image successfully downloaded to ..\public\InstagramImages\C4Yfdghu_dI.jpg
# 2614 {'is_event': True, 'event_name': 'Therapy Dogs Event', 'event_description': 'Destress with our Therapy Dogs and experience the healing powers of their paws', 'event_categories': ['WELLNESS'], 'start_time': '2024-03-22T12:00:00+00:00', 'end_time': '2024-03-22T13:00:00+00:00', 'location': 'SLC Black & Gold Room'}
# Image successfully downloaded to ..\public\InstagramImages\C4Q6BQDgEoh.jpg
# 2615 {'is_event': True, 'event_name': "WUSA's Name That Tune Trivia Night", 'event_description': 'Identify songs just by hearing a few notes', 'event_categories': ['MUSIC'], 'start_time': '2024-03-11T19:30:00+00:00', 'end_time': 'null', 'location': 'SLC Student Lounge 1123'}
# Image successfully downloaded to ..\public\InstagramImages\C4OlhyqgA2b.jpg
# 2616 no event detected
# 2617 no event detected
# 2618 {'is_event': True, 'event_name': 'Blue Jays Home Opener', 'event_description': 'Cheer on the Blue Jays as they face the Mariners at Rogers Centre', 'event_categories': ['SPORTS'], 'start_time': '2024-04-08T16:30:00+00:00', 'end_time': '2024-04-08T23:30:00+00:00', 'location': 'Rogers Centre'}
# Image successfully downloaded to ..\public\InstagramImages\C4LWg7NgV67.jpg
# 2619 no event detected
# 2620 {'is_event': True, 'event_name': "WUSA's Cultural Caravan", 'event_description': "Experience the diversity of our Waterloo community at WUSA's annual Cultural Caravan", 'event_categories': ['CULTURE'], 'start_time': '2024-03-21T19:00:00+00:00', 'end_time': '2024-03-21T22:00:00+00:00', 'location': 'SLC Great Hall'}
# Image successfully downloaded to ..\public\InstagramImages\C4GnwoxALt6.jpg
# 2621 no event detected
# 2622 {'is_event': True, 'event_name': 'Workshop Presentation', 'event_description': "Maryum Mohiuddin Ahmed on colonization's impacts on racialized women", 'event_categories': ['CULTURE'], 'start_time': '2024-03-04T18:00:00+00:00', 'end_time': '2024-03-04T19:30:00+00:00', 'location': 'RCH 309'}
# Image successfully downloaded to ..\public\InstagramImages\C36D-i8gLLF.jpg
# 2623 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C35nTW3g7du.jpg
# 2624 {'is_event': True, 'event_name': 'WUSA Trivia Night', 'event_description': 'Join us for trivia night with cool prizes', 'event_categories': ['SPORTS'], 'start_time': '2024-02-29T19:30:00+00:00', 'end_time': 'null', 'location': 'SLC Student Lounge 1123'}
# Image successfully downloaded to ..\public\InstagramImages\C30djw8gaXs.jpg
# 2625 {'is_event': True, 'event_name': "Toronto FC's Home Opener game", 'event_description': 'Watch Toronto FC take on Charlotte FC at BMO Field', 'event_categories': ['SPORTS'], 'start_time': '2024-03-09T12:00:00+00:00', 'end_time': '2024-03-09T19:00:00+00:00', 'location': 'Downtown Toronto, BMO Field'}
# Image successfully downloaded to ..\public\InstagramImages\C3lNXk1uUDG.jpg
# 2626 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C3k-ZJhgfpQ.jpg
# 2627 no event detected
# 2628 no event detected
# 2629 no event detected
# 2630 no event detected
# 2631 no event detected
# 2632 {'is_event': True, 'event_name': 'WUSA General Election', 'event_description': 'Vote in the WUSA general election to elect the Board of Directors', 'event_categories': ['CULTURE'], 'start_time': '2024-02-12T00:00:00+00:00', 'end_time': '2024-02-14T23:59:00+00:00', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C3P_h-rAof4.jpg
# 2633 no event detected
# 2634 no event detected
# 2635 no event detected
# 2636 {'is_event': True, 'event_name': 'Qigong Class', 'event_description': 'Qigong Class for inner peace and physical strength', 'event_categories': ['WELLNESS'], 'start_time': '2024-03-06T12:30:00+00:00', 'end_time': '2024-03-06T14:00:00+00:00', 'location': 'SLC Black & Gold Room'}
# Image successfully downloaded to ..\public\InstagramImages\C3IaY98Arq6.jpg
# 2637 {'is_event': True, 'event_name': 'Art Hive Session', 'event_description': 'Our second Art Hive session to unwind and recharge with fun, creative play', 'event_categories': ['CULTURE', 'WELLNESS'], 'start_time': '2024-02-15T13:00:00+00:00', 'end_time': '2024-02-15T15:00:00+00:00', 'location': 'SLC Black & Gold room'}
# Image successfully downloaded to ..\public\InstagramImages\C3GU3kvgZ3V.jpg
# 2638 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C3DK7RtgzBj.jpg
# 2639 {'is_event': True, 'event_name': 'WUSA Imprint Debate', 'event_description': 'Student reporters and Candidates debate for President role', 'event_categories': ['CULTURE'], 'start_time': '2024-02-08T17:00:00+00:00', 'end_time': '2024-02-08T19:00:00+00:00', 'location': 'Biology 1, Room 271'}
# Image successfully downloaded to ..\public\InstagramImages\C3BLrTrAu7Z.jpg
# 2640 {'is_event': True, 'event_name': 'Candidate Meet & Greet', 'event_description': 'Meet Your WUSA Board of Director candidates', 'event_categories': ['CULTURE', 'NETWORK'], 'start_time': '2024-02-07T14:00:00+00:00', 'end_time': '2024-02-07T15:00:00+00:00', 'location': 'SLC Black & Gold room'}
# Image successfully downloaded to ..\public\InstagramImages\C3BD_fSgqdv.jpg
# 2641 {'is_event': True, 'event_name': 'Snow Tubing Experience', 'event_description': 'Ultimate snow tubing experience at Chicopee Tube Park', 'event_categories': ['SPORTS'], 'start_time': '2024-02-11T17:00:00+00:00', 'end_time': '2024-02-11T21:00:00+00:00', 'location': 'Chicopee Tube Park'}
# Image successfully downloaded to ..\public\InstagramImages\C3AwwqnA0q1.jpg
# 2642 {'is_event': True, 'event_name': '2024-2025 WUSA Board of Directors Election', 'event_description': 'Learn about candidates, explore their platforms, and make an informed voting decision', 'event_categories': ['CULTURE'], 'start_time': '2024-02-12 00:00:00+00:00', 'end_time': '2024-02-14 23:59:00+00:00', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C2-e5y2gkRM.jpg
# 2643 no event detected
# 2644 {'is_event': True, 'event_name': 'Therapy Dogs', 'event_description': 'Therapy Dogs event for stress relief and happiness', 'event_categories': ['WELLNESS'], 'start_time': '2024-02-09T12:00:00+00:00', 'end_time': '2024-02-09T13:00:00+00:00', 'location': 'SLC Black & Gold Room'}
# Image successfully downloaded to ..\public\InstagramImages\C2-DQvagJz5.jpg
# 2645 no event detected
# 2646 no event detected
# 2647 {'is_event': True, 'event_name': 'WUSA Officer Debate', 'event_description': 'Get to know your candidates in the WUSA election', 'event_categories': ['CULTURE'], 'start_time': '2024-02-08T17:00:00+00:00', 'end_time': '2024-02-08T19:00:00+00:00', 'location': 'B1 271'}
# Image successfully downloaded to ..\public\InstagramImages\C22gAu9gac4.jpg
# 2648 no event detected
# 2649 no event detected
# 2650 no event detected
# 2651 no event detected
# 2652 {'is_event': True, 'event_name': 'WUSA Cultural Caravan', 'event_description': 'Celebrate the diversity of University of Waterloo community at this multicultural showcase', 'event_categories': ['CULTURE'], 'start_time': '2024-03-21T17:00:00+00:00', 'end_time': '2024-03-21T19:00:00+00:00', 'location': 'SLC Great Hall'}
# Image successfully downloaded to ..\public\InstagramImages\C2sxF0OgcLQ.jpg
# 2653 {'is_event': True, 'event_name': 'WUSA Election AMA', 'event_description': 'AMA with WUSA candidates on January 30th', 'event_categories': ['CULTURE'], 'start_time': '2024-01-30T00:00:00+00:00', 'end_time': 'nan', 'location': 'nan'}
# Image successfully downloaded to ..\public\InstagramImages\C2stk8CAwh_.jpg
# 2654 no event detected
# 2655 no event detected
# 2656 {'is_event': True, 'event_name': 'Candidate Meet & Greet', 'event_description': 'Meet WUSA Board of Director candidates on Jan 24th', 'event_categories': ['NETWORK', 'CULTURE'], 'start_time': '2024-01-24T18:00:00+00:00', 'end_time': '2024-01-24T20:00:00+00:00', 'location': 'SLC Multi-Purpose Room'}
# Image successfully downloaded to ..\public\InstagramImages\C2dNCHruw67.jpg
# 2657 {'is_event': True, 'event_name': 'Candidate Meet & Greet', 'event_description': 'Meet WUSA Board of Director candidates and ask questions', 'event_categories': ['CULTURE'], 'start_time': '2024-01-24T18:00:00+00:00', 'end_time': '2024-01-24T20:00:00+00:00', 'location': 'SLC Multi-Purpose room'}
# Image successfully downloaded to ..\public\InstagramImages\C2c1eOlAxvl.jpg
# 2658 {'is_event': True, 'event_name': 'Advocacy Mind Matters Series', 'event_description': 'Blend of learning and fun activities for well-being', 'event_categories': ['WELLNESS', 'CULTURE'], 'start_time': '2024-01-22T00:00:00+00:00', 'end_time': '2024-01-26T00:00:00+00:00', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C2PzZREAivp.jpg
# 2659 {'is_event': True, 'event_name': 'Consent & Crafts', 'event_description': 'Relax and get crafty with Consent & Crafts event on January 24th', 'event_categories': ['CULTURE'], 'start_time': '2024-01-24T12:00:00+00:00', 'end_time': '2024-01-24T16:00:00+00:00', 'location': 'SLC Lower Atrium (flex space)'}
# Image successfully downloaded to ..\public\InstagramImages\C2NavDHAWDK.jpg
# 2660 {'is_event': True, 'event_name': 'WUSA Campus Life Fair', 'event_description': 'Meet our services, learn about campus support, and get involved', 'event_categories': ['NETWORK', 'CULTURE'], 'start_time': '2024-01-24T11:00:00+00:00', 'end_time': '2024-01-24T14:00:00+00:00', 'location': 'SLC Great Hall'}
# Image successfully downloaded to ..\public\InstagramImages\C2NT4uLAwVM.jpg
# 2661 {'is_event': True, 'event_name': 'Therapy Dogs', 'event_description': 'Therapy Dogs at SLC Multi-Purpose Room for stress relief and activities', 'event_categories': ['WELLNESS'], 'start_time': '2024-01-23T12:00:00+00:00', 'end_time': '2024-01-23T16:00:00+00:00', 'location': 'SLC Multi-Purpose Room'}
# Image successfully downloaded to ..\public\InstagramImages\C2LRRHWrcHh.jpg
# 2662 {'is_event': True, 'event_name': 'Warriors Welcome Week - Sex Toy Bingo', 'event_description': 'Join us for an all-ages show and 19+ show at SLC Student Lounge', 'event_categories': ['CULTURE'], 'start_time': '2024-01-16T19:30:00+00:00', 'end_time': '2024-01-16T23:30:00+00:00', 'location': 'SLC Student Lounge'}
# Image successfully downloaded to ..\public\InstagramImages\C2Ay1eRAw00.jpg
# 2663 no event detected
# 2664 {'is_event': True, 'event_name': 'Esports Gaming Lounge', 'event_description': 'Esports action at the SLC Black & Gold Room', 'event_categories': ['GAMING'], 'start_time': '2024-01-15T00:00:00+00:00', 'end_time': '2024-01-19T00:00:00+00:00', 'location': 'SLC Black & Gold Room (2143)'}
# Image successfully downloaded to ..\public\InstagramImages\C19q2dIAWGn.jpg
# 2665 no event detected
# 2666 {'is_event': True, 'event_name': 'Trivia Night', 'event_description': 'Bring your competitive spirit & flex your random knowledge at Trivia Night', 'event_categories': ['TECH'], 'start_time': '2024-01-15T19:30:00+00:00', 'end_time': '2024-01-15T21:30:00+00:00', 'location': 'SLC Student Lounge'}
# Image successfully downloaded to ..\public\InstagramImages\C17HZkbAXsN.jpg
# 2667 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C14hflYLnko.jpg
# 2668 no event detected
# 2669 {'is_event': True, 'event_name': 'Warriors on Ice', 'event_description': 'Fun night of skating, food, and fun', 'event_categories': ['SPORTS'], 'start_time': '2024-01-18T19:00:00+00:00', 'end_time': '2024-01-18T22:00:00+00:00', 'location': 'CIF Arena'}
# Image successfully downloaded to ..\public\InstagramImages\C1upcdeuDqT.jpg
# 2670 {'is_event': True, 'event_name': "WUSA's Clubs & Societies Days", 'event_description': 'Find your passion and people among 250+ clubs', 'event_categories': ['TECH', 'NETWORK', 'CULTURE'], 'start_time': '2024-01-18T11:00:00+00:00', 'end_time': '2024-01-18T15:00:00+00:00', 'location': 'Student Life Centre'}
# Image successfully downloaded to ..\public\InstagramImages\C1uOVrfAXit.jpg
# 2671 no event detected
# 2672 no event detected
# 2673 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C1pglgEqyge.jpg
# 2674 {'is_event': True, 'event_name': "New Year's Eve 2.0 Bash", 'event_description': 'Extension of holiday festivities at the ultimate New Year’s Eve celebration', 'event_categories': ['MUSIC'], 'start_time': '2024-01-17T21:30:00+00:00', 'end_time': '2024-01-17T01:00:00+00:00', 'location': 'Maxwell’s Concerts & Events'}
# Image successfully downloaded to ..\public\InstagramImages\C1mwFefLSpM.jpg
# 2675 no event detected
# 2676 no event detected
# 2677 no event detected
# 2678 no event detected
# 2679 no event detected
# 2680 no event detected
# 2681 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C0UXWZ1goM3.jpg
# 2682 {'is_event': True, 'event_name': 'Therapy Dogs', 'event_description': 'Therapy Dogs event to reduce stress and anxiety', 'event_categories': ['WELLNESS'], 'start_time': '2023-11-24T12:00:00+00:00', 'end_time': '2023-11-24T13:00:00+00:00', 'location': 'SLC Black & Gold Room'}
# Image successfully downloaded to ..\public\InstagramImages\Cz_btBEAv4V.jpg
# 2683 no event detected
# 2684 no event detected
# 2685 {'is_event': True, 'event_name': 'Art Therapy', 'event_description': 'Discover the power of art therapy for relaxation and creativity', 'event_categories': ['CULTURE'], 'start_time': '2023-11-24T11:30:00+00:00', 'end_time': '2023-11-24T13:30:00+00:00', 'location': 'SLC Multi-purpose room'}
# Image successfully downloaded to ..\public\InstagramImages\CzwqdQUA8Dh.jpg
# 2686 no event detected
# 2687 no event detected
# 2688 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\CzouQSjAOFh.jpg
# 2689 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\CzmcmnVOs-2.jpg
# 2690 {'is_event': True, 'event_name': 'YourWUSA Decade Dance Party', 'event_description': "2000's Decade Dance Party with music and a throwback vibe", 'event_categories': ['CULTURE', 'MUSIC'], 'start_time': '2023-11-21T21:30:00+00:00', 'end_time': '2023-11-21T21:30:00+00:00', 'location': 'Maxwell’s'}
# Image successfully downloaded to ..\public\InstagramImages\CzlzLRJgS9t.jpg
# 2691 no event detected
# 2692 no event detected
# 2693 no event detected
# 2694 no event detected
# 2695 {'is_event': True, 'event_name': 'Midterm Costume Contest', 'event_description': 'Destress with Halloween fun', 'event_categories': ['CULTURE'], 'start_time': '2024-10-31T18:00:00+00:00', 'end_time': '2024-10-31T20:00:00+00:00', 'location': 'SLC Black and Gold Room'}
# Image successfully downloaded to ..\public\InstagramImages\DBjdysIxbBA.jpg
# 2696 {'is_event': True, 'event_name': 'Midterm Costume Contest', 'event_description': 'Destress with Halloween fun and costumes', 'event_categories': ['CULTURE'], 'start_time': '2024-10-31T18:00:00+00:00', 'end_time': '2024-10-31T20:00:00+00:00', 'location': 'SLC Black and Gold Room'}
# Image successfully downloaded to ..\public\InstagramImages\DBjdlm5xP2E.jpg
# 2697 no event detected
# 2698 {'is_event': True, 'event_name': 'PwC Canada RMS Networking Session', 'event_description': 'Career in Risk Modelling Services with PwC Canada, networking and learning opportunity', 'event_categories': ['NETWORK'], 'start_time': '2024-10-24T18:00:00+00:00', 'end_time': '2024-10-24T20:00:00+00:00', 'location': 'E2 1736'}
# Image successfully downloaded to ..\public\InstagramImages\DBOeXakgQbx.jpg
# 2699 {'is_event': True, 'event_name': 'Actuaries Tutorial Session', 'event_description': 'Coaching Actuaries platform tutorial for UW ActSci Club members', 'event_categories': ['TECH'], 'start_time': '2024-10-22T18:00:00+00:00', 'end_time': '2024-10-22T20:00:00+00:00', 'location': 'DWE 3518'}
# Image successfully downloaded to ..\public\InstagramImages\DBJrgbNg_cO.jpg
# 2700 {'is_event': True, 'event_name': 'SOA Info Session', 'event_description': 'SOA Info Session on actuarial career path and insurance industry', 'event_categories': ['TECH', 'NETWORK', 'CULTURE'], 'start_time': '2024-11-07T18:00:00+00:00', 'end_time': '2024-11-07T20:00:00+00:00', 'location': 'SLC Black & Gold'}
# Image successfully downloaded to ..\public\InstagramImages\DA9IXOrSwnN.jpg
# 2701 no event detected
# 2702 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\DA1OLr2J9vP.jpg
# 2703 no event detected
# 2704 {'is_event': True, 'event_name': 'ActSci 101 - Meet the Experts', 'event_description': 'Meet actuarial science experts and gain insights into the field', 'event_categories': ['TECH'], 'start_time': '2024-10-08T18:30:00+00:00', 'end_time': '2024-10-08T20:00:00+00:00', 'location': 'MC5501'}
# Image successfully downloaded to ..\public\InstagramImages\DAtn4NJyNKs.jpg
# 2705 {'is_event': True, 'event_name': 'ASNA Info Session', 'event_description': 'ASNA Convention info session and networking event', 'event_categories': ['NETWORK'], 'start_time': '2024-10-04T15:00:00+00:00', 'end_time': '2024-10-04T17:00:00+00:00', 'location': 'MC2034'}
# Image successfully downloaded to ..\public\InstagramImages\DAqyIorgMIF.jpg
# 2706 no event detected
# 2707 no event detected
# 2708 {'is_event': True, 'event_name': 'ASNA Info Session', 'event_description': 'Learn about ASNA and the 2025 Convention', 'event_categories': ['ACTUARIAL', 'NETWORK'], 'start_time': '2024-10-04T15:00:00+00:00', 'end_time': '2024-10-04T17:00:00+00:00', 'location': 'MC2034'}
# Image successfully downloaded to ..\public\InstagramImages\DAhNeCygp_V.jpg
# 2709 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\DAgvjZ5Jc0B.jpg
# 2710 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\DAd4jCbpeoH.jpg
# 2711 no event detected
# 2712 {'is_event': True, 'event_name': 'Mentorship Kickoff Event', 'event_description': 'Meet your mentor, learn about the program, and enjoy trivia and games', 'event_categories': ['TECH'], 'start_time': '2024-10-03T18:00:00+00:00', 'end_time': '2024-10-03T20:00:00+00:00', 'location': 'SLC Black & Gold'}
# Image successfully downloaded to ..\public\InstagramImages\DAa9c50O4Bh.jpg
# 2713 {'is_event': True, 'event_name': 'UW ActSci Beginning of Term Event', 'event_description': 'Beginning of Term Event with group activities, trivia, board games, and food', 'event_categories': ['CULTURE'], 'start_time': '2024-10-01T18:00:00+00:00', 'end_time': '2024-10-01T20:00:00+00:00', 'location': 'SLC Black & Gold Room'}
# Image successfully downloaded to ..\public\InstagramImages\DAV1FrSg3Mt.jpg
# 2714 {'is_event': True, 'event_name': 'Networking 101', 'event_description': 'Learn where to start with creating an application package', 'event_categories': ['NETWORK'], 'start_time': '2024-09-24T19:00:00+00:00', 'end_time': '2024-09-24T20:00:00+00:00', 'location': 'STC0060'}
# Image successfully downloaded to ..\public\InstagramImages\DAOL8NhuJd2.jpg
# 2715 no event detected
# 2716 no event detected
# 2717 {'is_event': True, 'event_name': 'Explore ActSci', 'event_description': 'Network with professionals from Equitable and learn about actuarial opportunities', 'event_categories': ['NETWORK', 'CULTURE'], 'start_time': '2024-09-26T18:00:00+00:00', 'end_time': '2024-09-26T20:00:00+00:00', 'location': 'MC 2017'}
# Image successfully downloaded to ..\public\InstagramImages\DAI-rBZOoMy.jpg
# 2718 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\DAGfH6VpYnB.jpg
# 2719 no event detected
# 2720 no event detected
# 2721 {'is_event': True, 'event_name': 'uwactsciclub Networking Event', 'event_description': 'Networking event with Pacific Life Re to learn about actuarial work and opportunities', 'event_categories': ['NETWORK'], 'start_time': '2024-09-19T18:00:00+00:00', 'end_time': '2024-09-19T20:00:00+00:00', 'location': 'MC2054'}
# Image successfully downloaded to ..\public\InstagramImages\C_-8_91gSJJ.jpg
# 2722 no event detected
# 2723 {'is_event': True, 'event_name': 'Bubbles & Bao with Munich Re', 'event_description': 'Network with Munich Re professionals and learn about 2025 Actuarial opportunities', 'event_categories': ['NETWORK'], 'start_time': '2024-09-16T18:30:00+00:00', 'end_time': '2024-09-16T20:00:00+00:00', 'location': 'MC 2034'}
# Image successfully downloaded to ..\public\InstagramImages\C_1UST8gMxd.jpg
# 2724 {'is_event': True, 'event_name': 'Networking Extravaganza', 'event_description': 'Networking event with three waves, business casual dress code', 'event_categories': ['NETWORK'], 'start_time': '2024-09-13T15:00:00+00:00', 'end_time': '2024-09-13T18:00:00+00:00', 'location': 'KW Crowne Plaza Hotel'}
# Image successfully downloaded to ..\public\InstagramImages\C_yL_HGuW7Q.jpg
# 2725 no event detected
# 2726 no event detected
# 2727 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C-LmnRZpv12.jpg
# 2728 no event detected
# 2729 no event detected
# 2730 no event detected
# 2731 no event detected
# 2732 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C9k_NKMJ7_B.jpg
# 2733 {'is_event': True, 'event_name': 'Beach Volleyball Tournament', 'event_description': 'Beach volleyball elimination bracket with prizes', 'event_categories': ['SPORTS'], 'start_time': '2024-07-24T18:00:00+00:00', 'end_time': '2024-07-24T20:00:00+00:00', 'location': 'CIF Beach Volleyball Courts'}
# Image successfully downloaded to ..\public\InstagramImages\C9fzJsXpFKD.jpg
# 2734 no event detected
# 2735 no event detected
# 2736 {'is_event': True, 'event_name': 'Actuarial Science 101 and Q&A', 'event_description': 'Actuarial Science 101 and Q&A session', 'event_categories': ['CULTURE'], 'start_time': '2024-07-11T18:00:00+00:00', 'end_time': '2024-07-11T20:00:00+00:00', 'location': 'MC 5501'}
# Image successfully downloaded to ..\public\InstagramImages\C9NhlR1pZZw.jpg
# 2737 no event detected
# 2738 no event detected
# 2739 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C9A-qM1JPb8.jpg
# 2740 {'is_event': True, 'event_name': 'UW ActSci Club Bonfire Midterm Destress', 'event_description': 'De-stress with UW ActSci Club at our Bonfire Midterm Destress social event', 'event_categories': ['TECH', 'WELLNESS'], 'start_time': '2024-07-04T18:00:00+00:00', 'end_time': '2024-07-04T20:00:00+00:00', 'location': 'Columbia Lake, Fire Pit 1'}
# Image successfully downloaded to ..\public\InstagramImages\C88VJz9taEE.jpg
# 2741 {'is_event': True, 'event_name': 'UW ACTS CI Club Networking Event', 'event_description': 'Outdoor Networking Event with industry professionals and fun activities', 'event_categories': ['NETWORK'], 'start_time': '2024-07-02 17:00:00+00:00', 'end_time': '2024-07-02 18:00:00+00:00', 'location': 'SLC Black & Gold Room'}
# Image successfully downloaded to ..\public\InstagramImages\C87m2xNJw_0.jpg
# 2742 {'is_event': True, 'event_name': 'Aviva Actuaries Networking Event', 'event_description': 'Network with Aviva Actuaries from 5:00 PM to 7:00 PM EST', 'event_categories': ['NETWORK'], 'start_time': '2024-07-02T17:00:00-04:00', 'end_time': '2024-07-02T19:00:00-04:00', 'location': 'SLC Black and Gold'}
# Image successfully downloaded to ..\public\InstagramImages\C85RJM2JRMB.jpg
# 2743 no event detected
# 2744 {'is_event': True, 'event_name': 'UW Act Sci Club Event', 'event_description': 'Meet with Sun Life Actuaries and learn about the actuarial profession', 'event_categories': ['NETWORK'], 'start_time': '2024-06-27T18:00:00+00:00', 'end_time': '2024-06-27T20:00:00+00:00', 'location': 'SLC Black and Gold room'}
# Image successfully downloaded to ..\public\InstagramImages\C8dGL1EJH4U.jpg
# 2745 no event detected
# 2746 {'is_event': True, 'event_name': 'Intact Networking Summer Event', 'event_description': 'Intact invites you to their Networking Summer Event', 'event_categories': ['NETWORK'], 'start_time': '2024-06-24T17:30:00+00:00', 'end_time': '2024-06-24T19:30:00+00:00', 'location': 'M3 Green'}
# Image successfully downloaded to ..\public\InstagramImages\C8U7vqsJOhd.jpg
# 2747 no event detected
# 2748 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C8Ky1rhJfIK.jpg
# 2749 {'is_event': True, 'event_name': 'ActSci Club Mentorship Social', 'event_description': 'Learn about Actuarial Science from upper-year mentors', 'event_categories': ['CULTURE'], 'start_time': '2024-06-13T18:00:00+00:00', 'end_time': '2024-06-13T20:00:00+00:00', 'location': 'STC 0010'}
# ...
# 2777 {'is_event': True, 'event_name': 'Exam FM Tutorial', 'event_description': 'Upcoming exam tutorial for actuarial science students', 'event_categories': [], 'start_time': '2024-03-07T18:00:00+00:00', 'end_time': '2024-03-07T20:00:00+00:00', 'location': 'RCH306'}
# Image successfully downloaded to ..\public\InstagramImages\C4G0ACfgRsz.jpg
# 2778 no event detected
# 2779 no event detected
# 2780 no event detected
# 2781 {'is_event': True, 'event_name': 'Careers in Risk', 'event_description': "Sonia Kundi's talk on risk management and business career", 'event_categories': ['NETWORK'], 'start_time': '2024-03-04T16:30:00+00:00', 'end_time': '2024-03-04T18:00:00+00:00', 'location': 'STC 0010'}
# Image successfully downloaded to ..\public\InstagramImages\C33CpoAA4Nx.jpg
# 2782 {'is_event': True, 'event_name': 'Actuarial Science Club Games Night', 'event_description': 'Relieve midterm stress with games and pinatas', 'event_categories': ['GAMING'], 'start_time': '2024-02-29T18:00:00+00:00', 'end_time': '2024-02-29T20:00:00+00:00', 'location': 'MC COMFY'}
# Image successfully downloaded to ..\public\InstagramImages\C31Z35KN1U7.jpg
# 2783 no event detected
# 2784 no event detected
# 2785 {'is_event': True, 'event_name': 'Actuarial Science 101 and Q&A session', 'event_description': 'Actuarial Science 101 Q&A session', 'event_categories': ['ACT-SCI'], 'start_time': '2024-02-15T18:00:00-05:00', 'end_time': '2024-02-15T20:00:00-05:00', 'location': 'SLC Black and Gold Room'}
# Image successfully downloaded to ..\public\InstagramImages\C3WRUIeNh8o.jpg
# 2786 no event detected
# 2787 {'is_event': True, 'event_name': 'Actuarial Science 101', 'event_description': 'Join us for Actuarial Science 101 and a Q&A session', 'event_categories': ['CULTURE'], 'start_time': '2024-02-15T18:00:00-05:00', 'end_time': '2024-02-15T20:00:00-05:00', 'location': 'SLC Black and Gold Room'}
# Image successfully downloaded to ..\public\InstagramImages\C3Ll_IFplDl.jpg
# 2788 {'is_event': True, 'event_name': 'ActSci Club Mentorship Social', 'event_description': 'ActSci Club Mentorship Social with food and games', 'event_categories': ['ACTUARIAL SCIENCE IS IN THE CULTURE CATEGORY BUT IT WAS NOT SPECIFIED HERE SO WE WILL USE NETWORK'], 'start_time': '2024-02-13T18:30:00+00:00', 'end_time': '2024-02-13T20:30:00+00:00', 'location': 'SLC Multipurpose Hall'}
# Image successfully downloaded to ..\public\InstagramImages\C3GOymdJPAn.jpg
# 2789 no event detected
# 2790 no event detected
# 2791 {'is_event': True, 'event_name': 'UW ActSci Club Social Event', 'event_description': 'Fun evening with games, food, and prizes', 'event_categories': ['ACTUARIAL SCIENCE'], 'start_time': '2024-02-01T18:00:00-05:00', 'end_time': '2024-02-01T20:00:00-05:00', 'location': 'SLC Black & Gold Room.'}
# Image successfully downloaded to ..\public\InstagramImages\C2iapCupt-2.jpg
# 2792 no event detected
# 2793 {'is_event': True, 'event_name': 'ActSci Club Event with Aviva', 'event_description': 'Networking event with Aviva, food and representatives from the company', 'event_categories': ['NETWORK'], 'start_time': 'null', 'end_time': 'null', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C2c0WgSA7PO.jpg
# 2794 no event detected
# 2795 {'is_event': True, 'event_name': 'Sun Life Actuaries Connect', 'event_description': 'Connect with Sun Life Actuaries and learn about the actuarial profession', 'event_categories': ['NETWORK'], 'start_time': '2024-01-23T18:00:00+00:00', 'end_time': '2024-01-23T20:00:00+00:00', 'location': 'SLC Black and Gold room'}
# Image successfully downloaded to ..\public\InstagramImages\C2Qn7fyg7zl.jpg
# 2796 no event detected
# 2797 no event detected
# 2798 {'is_event': True, 'event_name': 'UWaterloo Actuarial Club Networking Event', 'event_description': 'Networking event with Aviva, opportunity to learn about actuarial work and food', 'event_categories': ['NETWORK'], 'start_time': '2024-01-16T18:00:00+00:00', 'end_time': '2024-01-16T20:00:00+00:00', 'location': 'MC 2034'}
# Image successfully downloaded to ..\public\InstagramImages\C19_uKdJt8n.jpg
# 2799 no event detected
# 2800 no event detected
# 2801 no event detected
# 2802 {'is_event': True, 'event_name': 'uwactsciclub End-of-Term Celebration', 'event_description': 'Annual End-of-Term Celebration with food and activities', 'event_categories': ['SPORTS'], 'start_time': '2023-11-30T18:00:00+00:00', 'end_time': '2023-11-30T20:00:00+00:00', 'location': 'SLC Black and Gold Room'}
# Image successfully downloaded to ..\public\InstagramImages\C0NFBUypZmC.jpg
# 2803 {'is_event': True, 'event_name': 'CAS Industry Networking', 'event_description': 'Industry event with actuarial science focusing on CAS careers and exams', 'event_categories': ['NETWORK'], 'start_time': '2023-11-23T18:30:00+00:00', 'end_time': '2023-11-23T20:30:00+00:00', 'location': 'MC 4042'}
# Image successfully downloaded to ..\public\InstagramImages\Cz_evu-MjWG.jpg
# 2804 {'is_event': True, 'event_name': 'Networking Session at UWaterloo', 'event_description': 'Networking session with Sun Life Actuaries', 'event_categories': ['NETWORK'], 'start_time': '2023-11-27T18:00:00+00:00', 'end_time': '2023-11-27T20:00:00+00:00', 'location': 'SLC Black and Gold Room'}
# Image successfully downloaded to ..\public\InstagramImages\Cz9QMMMgF4x.jpg
# 2805 {'is_event': True, 'event_name': 'UW ACTSC IC Lab Talk', 'event_description': 'Actuarial science insights and career advice', 'event_categories': ['ACTUARIAL SCIENCE'], 'start_time': '2023-11-23T18:30:00+00:00', 'end_time': '2023-11-23T20:30:00+00:00', 'location': 'MC 4042'}
# Image successfully downloaded to ..\public\InstagramImages\Cz6aPk8r4Ot.jpg
# 2806 {'is_event': True, 'event_name': 'Excel/SQL Tutorial', 'event_description': 'Excel/SQL tutorial for actuarial work and data enthusiasts', 'event_categories': ['TECH'], 'start_time': '2023-11-20T18:00:00+00:00', 'end_time': '2023-11-20T20:00:00+00:00', 'location': 'MC 1085'}
# Image successfully downloaded to ..\public\InstagramImages\Czt14r_gJX0.jpg
# 2807 {'is_event': True, 'event_name': 'UW ACTS CI Club - Networking 101', 'event_description': 'Networking 101 presentation with food and club registration', 'event_categories': ['NETWORK'], 'start_time': '2023-11-13T18:00:00+00:00', 'end_time': '2023-11-13T20:00:00+00:00', 'location': 'MC 5501'}
# Image successfully downloaded to ..\public\InstagramImages\Czk1TupgE4J.jpg
# 2808 no event detected
# 2809 no event detected
# 2810 {'is_event': True, 'event_name': 'Fright Night', 'event_description': "WatSAM's Halloween event with Photobooth, Mask Decorating, and pizza", 'event_categories': ['CULTURE'], 'start_time': '2024-10-29T00:00:00+00:00', 'end_time': 'nan', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\DBXRpEMyHyG.jpg
# 2811 no event detected
# 2812 {'is_event': True, 'event_name': 'Monthly Microbe Spotlight', 'event_description': 'Fun and creative night featuring Comamonadaceae', 'event_categories': ['WELLNESS'], 'start_time': '2024-10-10T18:00:00+00:00', 'end_time': 'null', 'location': 'RCH 109'}
# Image successfully downloaded to ..\public\InstagramImages\DAq8FpRyHC8.jpg
# 2813 no event detected
# 2814 no event detected
# 2815 no event detected
# 2816 no event detected
# 2817 no event detected
# 2818 {'is_event': True, 'event_name': 'WatSAM Painting Social', 'event_description': 'Painting social with prizes', 'event_categories': ['DESIGN'], 'start_time': '2024-09-19T00:00:00+00:00', 'end_time': '2024-09-19T00:00:00+00:00', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C___bqJtjiw.jpg
# 2819 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C-wKFDPNNKK.jpg
# 2820 no event detected
# 2821 no event detected
# 2822 {'is_event': True, 'event_name': "S'mores and Spores Bonfire Night", 'event_description': "WatSAM's S'mores and Spores Bonfire Night with microbiology trivia, cup pong, and snacks", 'event_categories': ['WELLNESS', 'CULTURE'], 'start_time': '2024-07-25T18:00:00+00:00', 'end_time': 'null', 'location': 'Columbia Lake Fire Pit 1'}
# Image successfully downloaded to ..\public\InstagramImages\C9ycyPkNJWM.jpg
# 2823 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C9iKcNfJjBX.jpg
# 2824 no event detected
# 2825 no event detected
# 2826 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C88G3cqtZaa.jpg
# 2827 no event detected
# 2828 no event detected
# 2829 no event detected
# 2830 no event detected
# 2831 no event detected
# 2832 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C5919fZtzHA.jpg
# 2833 no event detected
# 2834 no event detected
# 2835 no event detected
# 2836 {'is_event': True, 'event_name': 'WatSAM Sip & Chat', 'event_description': 'Night of warm bakery treats and learning about microbiology research', 'event_categories': ['CULTURE', 'WELLNESS'], 'start_time': '2024-03-08T17:30:00+00:00', 'end_time': 'null', 'location': 'STC 0020'}
# Image successfully downloaded to ..\public\InstagramImages\C4Bnb6jJPIY.jpg
# 2837 no event detected
# 2838 no event detected
# 2839 no event detected
# 2840 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C2DTiXuJ2Ma.jpg
# 2841 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\DArwNNgALSA.jpg
# 2842 no event detected
# 2843 no event detected
# 2844 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C_11YU-A1G7.jpg
# 2845 no event detected
# 2846 no event detected
# 2847 no event detected
# 2848 no event detected
# 2849 no event detected
# 2850 no event detected
# 2851 no event detected
# 2852 no event detected
# 2853 no event detected
# 2854 no event detected
# 2855 no event detected
# 2856 {'is_event': True, 'event_name': 'AFOW Leadership Retreat', 'event_description': "AFOW's annual Leadership Retreat", 'event_categories': ['CULTURE'], 'start_time': '2024-03-13T23:59:00+00:00', 'end_time': 'nan', 'location': 'nan'}
# Image successfully downloaded to ..\public\InstagramImages\C4X7U28s6UC.jpg
# 2857 {'is_event': True, 'event_name': 'AFOW Leadership Retreat', 'event_description': 'Join AFOW for a day of games, food, and leadership experience', 'event_categories': ['SPORTS', 'NETWORK', 'CULTURE'], 'start_time': '2024-03-16T10:00:00+00:00', 'end_time': 'nan', 'location': 'nan'}
# Image successfully downloaded to ..\public\InstagramImages\C4TgMS_guNR.jpg
# 2858 no event detected
# 2859 no event detected
# 2860 no event detected
# 2861 no event detected
# 2862 no event detected
# 2863 no event detected
# 2864 no event detected
# 2865 no event detected
# 2866 no event detected
# 2867 no event detected
# 2868 no event detected
# 2869 no event detected
# 2870 {'is_event': True, 'event_name': 'TSA Live Soccer Match', 'event_description': 'Experience Fenerbahçe vs Galatasaray soccer match with snacks and drinks', 'event_categories': ['SPORTS'], 'start_time': '2024-04-07T14:30:00+00:00', 'end_time': 'nan', 'location': 'EIT 1015.'}
# Image successfully downloaded to ..\public\InstagramImages\C5EtAVDA3sk.jpg
# 2871 {'is_event': True, 'event_name': 'TSA Iftar Dinner', 'event_description': 'Turkish food and live music by Juneyt Yetkiner', 'event_categories': ['CULTURE'], 'start_time': '2024-04-05T19:30:00+00:00', 'end_time': '2024-04-05T22:30:00+00:00', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C5AME2Ns2b6.jpg
# 2872 {'is_event': True, 'event_name': 'Chem 120 Review Session', 'event_description': "Chem 120's Test 2 review session with food and jeopardy game", 'event_categories': ['CULTURE'], 'start_time': '2024-11-04T17:30:00+00:00', 'end_time': '2024-11-04T19:30:00+00:00', 'location': 'RCH 302'}
# Warning: File already exists at ..\public\InstagramImages\DB2VF2es5in.jpg
# 2873 no event detected
# 2874 no event detected
# 2875 {'is_event': True, 'event_name': 'uw_bmsa Fright Night', 'event_description': 'Spooky fun with Pumpkin Painting and snacks', 'event_categories': ['CULTURE'], 'start_time': '2024-10-29T00:00:00+00:00', 'end_time': 'null', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\DBWwT-VRmp0.jpg
# 2876 {'is_event': True, 'event_name': 'Crafts and Cartoons Night', 'event_description': 'Join us for a creative evening with painting, origami, etc. and enjoy childhood cartoons', 'event_categories': ['CULTURE'], 'start_time': '2024-10-09T18:00:00+00:00', 'end_time': '2024-10-09T20:00:00+00:00', 'location': 'SLC Black and Gold room'}
# Image successfully downloaded to ..\public\InstagramImages\DAmHP7gyVYT.jpg
# 2877 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': 'STC Foyer'}
# Image successfully downloaded to ..\public\InstagramImages\DAOgt6QpR9C.jpg
# 2878 no event detected
# 2879 no event detected
# 2880 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C_Ghw6lJeaT.jpg
# 2881 no event detected
# 2882 {'is_event': True, 'event_name': 'UW BMSA Study Cafe', 'event_description': 'Build your own exam kits at our study cafe', 'event_categories': ['NETWORK', 'CULTURE'], 'start_time': '2024-07-24T14:30:00+00:00', 'end_time': '2024-07-24T16:30:00+00:00', 'location': 'STC room 0060'}
# Image successfully downloaded to ..\public\InstagramImages\C9odA_SNnym.jpg
# 2883 {'is_event': False, 'event_name': '', 'event_description': '', 'event_categories': [], 'start_time': '', 'end_time': '', 'location': ''}
# Image successfully downloaded to ..\public\InstagramImages\C8agCLSpwac.jpg
# 2884 no event detected
# 2885 {'is_event': True, 'event_name': 'BMSA Paint Social', 'event_description': 'Paint Social afternoon with tote bags and canvases', 'event_categories': ['DESIGN'], 'start_time': '2024-06-13T14:30:00+00:00', 'end_time': '2024-06-13T16:30:00+00:00', 'location': 'STC 0060'}
# Image successfully downloaded to ..\public\InstagramImages\C8DHdjby0f8.jpg
# 2886 no event detected
# 2887 no event detected
# 2888 no event detected
# 2889 {'is_event': True, 'event_name': 'Student-Prof Night', 'event_description': 'Student-Prof night this Wednesday', 'event_categories': [], 'start_time': '2024-04-03T00:00:00+00:00', 'end_time': '2024-04-03T00:00:00+00:00', 'location': 'null'}
# Image successfully downloaded to ..\public\InstagramImages\C5NPMgQAWbd.jpg
# 2890 no event detected
# 2891 no event detected
# 2892 no event detected
# 2893 no event detected
# 2894 no event detected
# 2895 {'is_event': True, 'event_name': 'Genevieve Meet and Greet', 'event_description': 'Meet with Genevieve', 'event_categories': ['CULTURE'], 'start_time': '2024-03-13T17:30:00+00:00', 'end_time': '2024-03-13T17:30:00+00:00', 'location': 'STC 0020'}
# Image successfully downloaded to ..\public\InstagramImages\C4QbNvrro5a.jpg
# 2896 no event detected
# 2897 {'is_event': True, 'event_name': 'Boba and Paint Night', 'event_description': 'Soothing evening of creativity and relaxation', 'event_categories': ['WELLNESS'], 'start_time': '2024-03-04T18:00:00+00:00', 'end_time': '2024-03-04T20:00:00+00:00', 'location': 'B1 271'}
# Image successfully downloaded to ..\public\InstagramImages\C35FZTOLu1o.jpg
# 2898 no event detected
# 2899 no event detected

# %%
#RAG Processing
import os
from dotenv import load_dotenv
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd

load_dotenv()
uri = os.getenv('DATABASE_URI')
client = MongoClient(uri, server_api=ServerApi('1'))
db = client['Instagram']
collection = db["Events"]

#time conversion and edit formats
from datetime import datetime
import time

postsDf.reset_index(drop=True)
postsDf = postsDf.fillna(value="None")
postsDf.drop(postsDf.columns[postsDf.columns.str.contains(
    'unnamed', case=False)], axis=1, inplace=True)

for index, row in postsDf.iterrows():
    if row["is_event"] == True:
      row_dict = row["event_details"]
      try:
        conStart = datetime.fromisoformat(row_dict["start_time"])
        unixStart = time.mktime(conStart.timetuple()) 
        try:
          conEnd = datetime.fromisoformat(row_dict["end_time"])
          unixEnd = time.mktime(conEnd.timetuple())
        except:
          unixEnd = None
        row_dict["start_time"]=unixStart
        row_dict["end_time"]=unixEnd
        postsDf.at[index, "event_details"] = row_dict
        print(unixStart,unixEnd)
      except:
        postsDf.at[index, "is_event"] = False
        err = f'Start failed {row_dict["start_time"]}'
        
together_api_key = os.getenv('TOGETHER_API')


#code for embedding
embedding_model_string = 'BAAI/bge-large-en-v1.5' # model API string from Together.

def generate_embedding(input_texts: List[str], model_api_string: str) -> List[List[float]]:
  together_client = Together(api_key=together_api_key)
  outputs = together_client.embeddings.create(
      input=input_texts,
      model=model_api_string,
  )
  return [x.embedding for x in outputs.data]

for index, row in postsDf.iterrows():    
    if row['event_details'] != "None":
      try:
        row_dict = {}
        for column in postsDf.columns.tolist():
          if column in ['account','date','caption','accessibility_caption','url','likes','display_photo']:
            row_dict[column] = row[column]
        row_dict["embedded"] = generate_embedding(row["processed_json"], embedding_model_string)  
        row_dict["event_details"] = row["event_details"]
        result = collection.insert_one(row_dict)
        print(f"Inserted document ID: {result.inserted_id}")
        time.sleep(1)
      except Exception as err:
         print("failure:", "err", row["processed_json"])

#Updating Events.json

def download_future_events_to_json(output_file):
    # Get current Unix timestamp
    current_timestamp = int(time.time())

    # Connect to MongoDB
    load_dotenv()
    uri = os.getenv('DATABASE_URI')
    client = MongoClient(uri, server_api=ServerApi('1'))
    db = client['Instagram']
    collection = db["Events"]

    # Query for future events
    query = {}
    future_events = list(collection.find(query))

    # Convert ObjectId to string for JSON serialization
    for event in future_events:
        event['_id'] = str(event['_id'])
        event['embedded'] = ""
    # Write to JSON file
    with open(output_file, 'w') as f:
        json.dump(future_events, f, indent=2)

    # Close the MongoDB connection
    client.close()

    return future_events


future_events = download_future_events_to_json(output_file)
# Out:
# 1717679700.0 None
# 1715882400.0 1715886000.0
# 1711981800.0 1711985400.0
# 1712030400.0 1712030400.0
# 1710946800.0 1710950400.0
# 1727564400.0 1727571600.0
# 1730822400.0 1730833200.0
# 1729116000.0 1729054800.0
# 1729974600.0 1729921500.0
# 1727280000.0 1727285400.0
# 1726671600.0 1726682400.0
# 1726671600.0 1726682400.0
# 1726113600.0 1726116300.0
# 1725681600.0 None
# 1725681600.0 1725681600.0
# 1726068600.0 1726070400.0
# 1726005600.0 1726027140.0
# 1725926400.0 None
# 1725888600.0 None
# 1725890400.0 1726192800.0
# 1725548400.0 1725559200.0
# 1725681600.0 None
# 1725681600.0 None
# 1725747300.0 None
# 1725681600.0 None
# 1725681600.0 1725681600.0
# 1715907600.0 1715914800.0
# 1715907600.0 None
# 1715648400.0 None
# 1715778000.0 1715788800.0
# 1715907600.0 None
# 1715821200.0 1715745600.0
# 1715727600.0 1715736600.0
# 1715608800.0 1715911200.0
# 1715648400.0 1715666400.0
# 1715614200.0 1715616000.0
# 1711472400.0 None
# 1711573200.0 None
# 1710626400.0 1710561600.0
# 1710804600.0 None
# 1710356400.0 1710360000.0
# 1711123200.0 1711126800.0
# 1710199800.0 None
# 1712608200.0 1712633400.0
# 1711062000.0 1711072800.0
# 1709593200.0 1709598600.0
# 1709253000.0 None
# 1710003600.0 1710028800.0
# 1707714000.0 1707973140.0
# 1709746200.0 1709751600.0
# 1708020000.0 1708027200.0
# 1707429600.0 1707436800.0
# 1707332400.0 1707336000.0
# 1707688800.0 1707703200.0
# 1707714000.0 1707973140.0
# 1707498000.0 1707501600.0
# 1707429600.0 1707436800.0
# 1711054800.0 1711062000.0
# 1706590800.0 None
# 1706137200.0 1706144400.0
# 1706137200.0 1706144400.0
# 1705899600.0 1706245200.0
# 1706115600.0 1706130000.0
# 1706112000.0 1706122800.0
# 1706029200.0 1706043600.0
# 1705451400.0 1705465800.0
# 1705294800.0 1705640400.0
# 1705365000.0 1705372200.0
# 1705622400.0 1705633200.0
# 1705593600.0 1705608000.0
# 1705545000.0 1705471200.0
# 1700845200.0 1700848800.0
# 1700843400.0 1700850600.0
# 1700620200.0 1700620200.0
# 1730412000.0 1730419200.0
# 1730412000.0 1730419200.0
# 1729807200.0 1729814400.0
# 1729634400.0 1729641600.0
# 1731020400.0 1731027600.0
# 1728426600.0 1728432000.0
# 1728068400.0 1728075600.0
# 1728068400.0 1728075600.0
# 1727992800.0 1728000000.0
# 1727820000.0 1727827200.0
# 1727218800.0 1727222400.0
# 1727388000.0 1727395200.0
# 1726783200.0 1726790400.0
# 1726525800.0 1726531200.0
# 1726254000.0 1726264800.0
# 1721858400.0 1721865600.0
# 1720735200.0 1720742400.0
# 1720130400.0 1720137600.0
# 1719954000.0 1719957600.0
# 1719954000.0 1719961200.0
# 1719525600.0 1719532800.0
# 1719264600.0 1719271800.0
# 1718316000.0 1718323200.0
# 1717711200.0 1717725600.0
# 1717110000.0 1717117200.0
# 1715900400.0 1715907600.0
# 1715205600.0 1715212800.0
# 1711663200.0 1711670400.0
# 1710280800.0 1710286200.0
# 1709852400.0 1709859600.0
# 1709587800.0 1709593200.0
# 1709247600.0 1709254800.0
# 1708038000.0 1708045200.0
# 1708038000.0 1708045200.0
# 1707867000.0 1707874200.0
# 1706828400.0 1706835600.0
# 1706050800.0 1706058000.0
# 1705446000.0 1705453200.0
# 1701385200.0 1701392400.0
# 1700782200.0 1700789400.0
# 1701126000.0 1701133200.0
# 1700782200.0 1700789400.0
# 1700521200.0 1700528400.0
# 1699916400.0 1699923600.0
# 1730174400.0 None
# 1728597600.0 None
# 1726718400.0 1726718400.0
# 1721944800.0 None
# 1709937000.0 None
# 1710388740.0 None
# 1710597600.0 None
# 1712514600.0 None
# 1712359800.0 1712370600.0
# 1730759400.0 1730766600.0
# 1730174400.0 None
# 1728511200.0 1728518400.0
# 1721845800.0 1721853000.0
# 1718303400.0 1718310600.0
# 1712116800.0 1712116800.0
# 1710365400.0 1710365400.0
# 1709593200.0 1709600400.0
# Inserted document ID: 6729a07238120b048654943c
# Inserted document ID: 6729a07438120b048654943d
# Inserted document ID: 6729a07538120b048654943e
# Inserted document ID: 6729a07738120b048654943f
# Inserted document ID: 6729a07838120b0486549440
# Inserted document ID: 6729a07938120b0486549441
# Inserted document ID: 6729a07b38120b0486549442
# Inserted document ID: 6729a07c38120b0486549443
# Inserted document ID: 6729a07e38120b0486549444
# Inserted document ID: 6729a07f38120b0486549445
# Inserted document ID: 6729a08038120b0486549446
# Inserted document ID: 6729a08238120b0486549447
# Inserted document ID: 6729a08338120b0486549448
# Inserted document ID: 6729a08438120b0486549449
# Inserted document ID: 6729a08638120b048654944a
# Inserted document ID: 6729a08738120b048654944b
# Inserted document ID: 6729a08838120b048654944c
# Inserted document ID: 6729a08a38120b048654944d
# Inserted document ID: 6729a08b38120b048654944e
# Inserted document ID: 6729a08c38120b048654944f
# Inserted document ID: 6729a08e38120b0486549450
# Inserted document ID: 6729a08f38120b0486549451
# Inserted document ID: 6729a09138120b0486549452
# Inserted document ID: 6729a09238120b0486549453
# Inserted document ID: 6729a09338120b0486549454
# Inserted document ID: 6729a09538120b0486549455
# Inserted document ID: 6729a09738120b0486549456
# Inserted document ID: 6729a09838120b0486549457
# Inserted document ID: 6729a09938120b0486549458
# Inserted document ID: 6729a09b38120b0486549459
# Inserted document ID: 6729a09c38120b048654945a
# Inserted document ID: 6729a09e38120b048654945b
# Inserted document ID: 6729a09f38120b048654945c
# Inserted document ID: 6729a0a238120b048654945d
# Inserted document ID: 6729a0a538120b048654945e
# Inserted document ID: 6729a0a738120b048654945f
# Inserted document ID: 6729a0aa38120b0486549460
# Inserted document ID: 6729a0ac38120b0486549461
# Inserted document ID: 6729a0ae38120b0486549462
# Inserted document ID: 6729a0af38120b0486549463
# Inserted document ID: 6729a0b138120b0486549464
# Inserted document ID: 6729a0b338120b0486549465
# Inserted document ID: 6729a0b438120b0486549466
# Inserted document ID: 6729a0b638120b0486549467
# Inserted document ID: 6729a0b738120b0486549468
# Inserted document ID: 6729a0b938120b0486549469
# Inserted document ID: 6729a0ba38120b048654946a
# Inserted document ID: 6729a0bc38120b048654946b
# Inserted document ID: 6729a0bd38120b048654946c
# Inserted document ID: 6729a0bf38120b048654946d
# Inserted document ID: 6729a0c138120b048654946e
# Inserted document ID: 6729a0c238120b048654946f
# Inserted document ID: 6729a0c438120b0486549470
# Inserted document ID: 6729a0c538120b0486549471
# Inserted document ID: 6729a0c738120b0486549472
# Inserted document ID: 6729a0c938120b0486549473
# Inserted document ID: 6729a0ca38120b0486549474
# Inserted document ID: 6729a0cc38120b0486549475
# Inserted document ID: 6729a0ce38120b0486549476
# Inserted document ID: 6729a0cf38120b0486549477
# Inserted document ID: 6729a0d138120b0486549478
# Inserted document ID: 6729a0d238120b0486549479
# Inserted document ID: 6729a0d438120b048654947a
# Inserted document ID: 6729a0d538120b048654947b
# Inserted document ID: 6729a0d738120b048654947c
# Inserted document ID: 6729a0d838120b048654947d
# Inserted document ID: 6729a0da38120b048654947e
# Inserted document ID: 6729a0db38120b048654947f
# Inserted document ID: 6729a0dc38120b0486549480
# Inserted document ID: 6729a0de38120b0486549481
# Inserted document ID: 6729a0df38120b0486549482
# Inserted document ID: 6729a0e138120b0486549483
# Inserted document ID: 6729a0e238120b0486549484
# Inserted document ID: 6729a0e338120b0486549485
# Inserted document ID: 6729a0e538120b0486549486
# Inserted document ID: 6729a0e638120b0486549487
# Inserted document ID: 6729a0e738120b0486549488
# Inserted document ID: 6729a0e938120b0486549489
# Inserted document ID: 6729a0ea38120b048654948a
# Inserted document ID: 6729a0eb38120b048654948b
# Inserted document ID: 6729a0ed38120b048654948c
# Inserted document ID: 6729a0ee38120b048654948d
# Inserted document ID: 6729a0f038120b048654948e
# Inserted document ID: 6729a0f138120b048654948f
# Inserted document ID: 6729a0f338120b0486549490
# Inserted document ID: 6729a0f438120b0486549491
# Inserted document ID: 6729a0f538120b0486549492
# Inserted document ID: 6729a0f738120b0486549493
# Inserted document ID: 6729a0f838120b0486549494
# Inserted document ID: 6729a0f938120b0486549495
# Inserted document ID: 6729a0fb38120b0486549496
# Inserted document ID: 6729a0fc38120b0486549497
# Inserted document ID: 6729a0fd38120b0486549498
# Inserted document ID: 6729a0ff38120b0486549499
# Inserted document ID: 6729a10038120b048654949a
# Inserted document ID: 6729a10138120b048654949b
# Inserted document ID: 6729a10338120b048654949c
# Inserted document ID: 6729a10438120b048654949d
# Inserted document ID: 6729a10538120b048654949e
# Inserted document ID: 6729a10738120b048654949f
# Inserted document ID: 6729a10938120b04865494a0
# Inserted document ID: 6729a10a38120b04865494a1
# Inserted document ID: 6729a10b38120b04865494a2
# Inserted document ID: 6729a10d38120b04865494a3
# Inserted document ID: 6729a10e38120b04865494a4
# Inserted document ID: 6729a10f38120b04865494a5
# Inserted document ID: 6729a11138120b04865494a6
# Inserted document ID: 6729a11338120b04865494a7
# Inserted document ID: 6729a11438120b04865494a8
# Inserted document ID: 6729a11538120b04865494a9
# Inserted document ID: 6729a11738120b04865494aa
# Inserted document ID: 6729a11838120b04865494ab
# Inserted document ID: 6729a11938120b04865494ac
# Inserted document ID: 6729a11b38120b04865494ad
# Inserted document ID: 6729a11c38120b04865494ae
# Inserted document ID: 6729a11d38120b04865494af
# Inserted document ID: 6729a11f38120b04865494b0
# Inserted document ID: 6729a12038120b04865494b1
# Inserted document ID: 6729a12138120b04865494b2
# Inserted document ID: 6729a12338120b04865494b3
# Inserted document ID: 6729a12438120b04865494b4
# Inserted document ID: 6729a12538120b04865494b5
# Inserted document ID: 6729a12738120b04865494b6
# Inserted document ID: 6729a12838120b04865494b7
# Inserted document ID: 6729a12a38120b04865494b8
# Inserted document ID: 6729a12b38120b04865494b9
# Inserted document ID: 6729a12c38120b04865494ba
# Inserted document ID: 6729a12e38120b04865494bb
# Inserted document ID: 6729a12f38120b04865494bc
# Inserted document ID: 6729a13038120b04865494bd
# Inserted document ID: 6729a13238120b04865494be
# Inserted document ID: 6729a13338120b04865494bf
# Inserted document ID: 6729a13438120b04865494c0
# Inserted document ID: 6729a13638120b04865494c1
# Inserted document ID: 6729a13738120b04865494c2
# Inserted document ID: 6729a13938120b04865494c3
# Inserted document ID: 6729a13a38120b04865494c4
# Inserted document ID: 6729a13b38120b04865494c5
# Inserted document ID: 6729a13d38120b04865494c6
# Inserted document ID: 6729a13e38120b04865494c7
# Inserted document ID: 6729a13f38120b04865494c8
# Inserted document ID: 6729a14138120b04865494c9
# Inserted document ID: 6729a14238120b04865494ca
# Inserted document ID: 6729a14438120b04865494cb
# Inserted document ID: 6729a14538120b04865494cc
# Inserted document ID: 6729a14638120b04865494cd
# Inserted document ID: 6729a14838120b04865494ce
# Inserted document ID: 6729a14938120b04865494cf
# Inserted document ID: 6729a14b38120b04865494d0
# Inserted document ID: 6729a14c38120b04865494d1
# Inserted document ID: 6729a14d38120b04865494d2
# Inserted document ID: 6729a14f38120b04865494d3
# Inserted document ID: 6729a15038120b04865494d4
# Inserted document ID: 6729a15138120b04865494d5
# Inserted document ID: 6729a15338120b04865494d6
# Inserted document ID: 6729a15438120b04865494d7
# Inserted document ID: 6729a15638120b04865494d8
# Inserted document ID: 6729a15738120b04865494d9
# Inserted document ID: 6729a15838120b04865494da
# Inserted document ID: 6729a15a38120b04865494db
# Inserted document ID: 6729a15b38120b04865494dc
# Inserted document ID: 6729a15c38120b04865494dd
# Inserted document ID: 6729a15e38120b04865494de
# Inserted document ID: 6729a15f38120b04865494df
# Inserted document ID: 6729a16038120b04865494e0
# Inserted document ID: 6729a16238120b04865494e1
# Inserted document ID: 6729a16338120b04865494e2
# Inserted document ID: 6729a16438120b04865494e3
# Inserted document ID: 6729a16638120b04865494e4
# Inserted document ID: 6729a16738120b04865494e5
# Inserted document ID: 6729a16938120b04865494e6
# Inserted document ID: 6729a16a38120b04865494e7
# Inserted document ID: 6729a16c38120b04865494e8
# Inserted document ID: 6729a16d38120b04865494e9
# Inserted document ID: 6729a16e38120b04865494ea
# Inserted document ID: 6729a16f38120b04865494eb
# Inserted document ID: 6729a17138120b04865494ec
# Inserted document ID: 6729a17238120b04865494ed
# Inserted document ID: 6729a17438120b04865494ee
# Inserted document ID: 6729a17538120b04865494ef
# Inserted document ID: 6729a17638120b04865494f0
